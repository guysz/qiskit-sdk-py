# %%
from project_common import *

# %%
betas = [(0.7, 0.1, 0.2), (0.3, 0.4, 0.3), (0.5,0.4,0.1)]

# %%
x1, y1 = outer_runner(qobj1, betas[0])
x2, y2 = outer_runner(qobj1, betas[1])
x3, y3 = outer_runner(qobj1, betas[2])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)

plt.legend(['beta1', 'beta2', 'beta3'], loc='upper left')
